# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
days = [i for i in range(1,16)]
temperature = [j for j in range(32,47)]
temp_df = pd.DataFrame({"days":days,"temperature":temperature})
temp_df
# Out:
#     days  temperature
# 0      1           32
# 1      2           33
# 2      3           34
# 3      4           35
# 4      5           36
# 5      6           37
# 6      7           38
# 7      8           39
# 8      9           40
# 9     10           41
# 10    11           42
# 11    12           43
# 12    13           44
# 13    14           45
# 14    15           46

# %%
sns.lineplot(x = "days",y = "temperature",data = temp_df,)
plt.show()

# %%
tips_df = sns.load_dataset('tips')
a = tips_df[['total_bill','tip']]
type(a)
arr = np.array(a).reshape(8,61)
arr
# Out:
# array([[16.99,  1.01, 10.34,  1.66, 21.01,  3.5 , 23.68,  3.31, 24.59,
#          3.61, 25.29,  4.71,  8.77,  2.  , 26.88,  3.12, 15.04,  1.96,
#         14.78,  3.23, 10.27,  1.71, 35.26,  5.  , 15.42,  1.57, 18.43,
#          3.  , 14.83,  3.02, 21.58,  3.92, 10.33,  1.67, 16.29,  3.71,
#         16.97,  3.5 , 20.65,  3.35, 17.92,  4.08, 20.29,  2.75, 15.77,
#          2.23, 39.42,  7.58, 19.82,  3.18, 17.81,  2.34, 13.37,  2.  ,
#         12.69,  2.  , 21.7 ,  4.3 , 19.65,  3.  ,  9.55],
#        [ 1.45, 18.35,  2.5 , 15.06,  3.  , 20.69,  2.45, 17.78,  3.27,
#         24.06,  3.6 , 16.31,  2.  , 16.93,  3.07, 18.69,  2.31, 31.27,
#          5.  , 16.04,  2.24, 17.46,  2.54, 13.94,  3.06,  9.68,  1.32,
#         30.4 ,  5.6 , 18.29,  3.  , 22.23,  5.  , 32.4 ,  6.  , 28.55,
#          2.05, 18.04,  3.  , 12.54,  2.5 , 10.29,  2.6 , 34.81,  5.2 ,
#          9.94,  1.56, 25.56,  4.34, 19.49,  3.51, 38.01,  3.  , 26.41,
#          1.5 , 11.24,  1.76, 48.27,  6.73, 20.29,  3.21],
# ...

# %%
sns.lineplot(x = "total_bill" , y = "tip",data = tips_df)
plt.show()

# %%
sns.lineplot(  x = "tip",y = "total_bill",data = tips_df)
plt.show()

# %%
sns.lineplot(  x = "size",y = "total_bill",data = tips_df,hue = "sex",style = "day",palette = "magma",dashes = False,markers = ["o","<",">","*"])
plt.show()

# %%
sns.distplot(tips_df["total_bill"],bins = 100,hist = True,color = 'r',rug = True)
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_31048\865463493.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],bins = 100,hist = True,color = 'r',rug = True)

# %%
pg = sns.load_dataset("penguins")
pg
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data = pg,x = "body_mass_g",bins = 100,kde = True,color="m")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.barplot(x = "day",y = "total_bill",data = tips_df,hue = "sex"error)
plt.show()

# %%
order = ['Sun','Thur','Fri','Sat']
sns.barplot(x = "day",y = "total_bill",data = tips_df,hue = "sex",order = order )
plt.show()

# %%
hue_order = ['Female','Male']
sns.barplot(x = "day",y = "total_bill",hue = "sex",data = tips_df,order = order ,hue_order = hue_order)
plt.show()

# %%
sns.barplot(x = "day",y = "total_bill",hue = "sex",data = tips_df,estimator = np.mean)
plt.show()

# %%
sns.barplot(x = "day",y = "total_bill",hue = "sex",data = tips_df,order = order ,hue_order = hue_order,color = 'r')
plt.show()

# %%
sns.barplot(x = "day",y = "total_bill",hue = "sex",data = tips_df,order = order ,hue_order = hue_order,palette = "magma",errwidth = 6,errcolor = 'g')
plt.show()

# %%
 df = sns.load_dataset('titanic')

# %%
df

# %%
sns.scatterplot(x = "age",y = "fare",data = df)
plt.show()

# %%
sns.scatterplot(x = "age",y = "fare",data = df,hue = "sex")
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.scatterplot(x = "age",y = "fare",data = df,hue = "sex",style = "who",size = "who")
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = "age",y = "fare",data = df)
sns.lineplot(x = "age",y = "fare",data = df)
sns.barplot(x = "age",y = "fare",data = df)
plt.show()

# %%
arr = np.linspace(1,5,12).reshape(4,3)
arr
# Out:
# array([[1.        , 1.36363636, 1.72727273],
#        [2.09090909, 2.45454545, 2.81818182],
#        [3.18181818, 3.54545455, 3.90909091],
#        [4.27272727, 4.63636364, 5.        ]])

# %%
sns.heatmap(arr)
# Out:
# <Axes: >
