# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("diabetes.csv")
df.info()
df.keys()
pd.unique(df['Pregnancies'])
pd.eval("double_age = df.Age * 2",target = df,inplace = True)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 2                       0.672   32        1          64
# 3                       0.167   21        0          42
# 4                       2.288   33        1          66
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [768 rows x 10 columns]

# %%
df.describe()
df.iloc[1:3,1:4]
df.loc[(df['Age'] > 40)]
df[df.index == 5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome  double_age
# 5                     0.201   30        0          60

# %%
df.describe(percentiles=[0.3, 0.5, 0.7])
df.describe(exclude=[int])
# Out:
#               BMI  DiabetesPedigreeFunction
# count  768.000000                768.000000
# mean    31.992578                  0.471876
# std      7.884160                  0.331329
# min      0.000000                  0.078000
# 25%     27.300000                  0.243750
# 50%     32.000000                  0.372500
# 75%     36.600000                  0.626250
# max     67.100000                  2.420000

# %%
df.shape # Get the number of rows and columns
# Out:
# (768, 10)

# %%
df.shape[0] # Get the number of rows only
# Out:
# 768

# %%
df.shape[1] # Get the number of columns only
# Out:
# 10

# %%
df.columns
list(df.columns)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome',
#  'double_age']

# %%
df2 = df.copy()

# %%
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 2                       0.672   32        1          64
# 3                       0.167   21        0          42
# 4                       2.288   33        1          66
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [768 rows x 10 columns]

# %%
df2.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# double_age                  0
# dtype: int64

# %%
df2.loc[2:5,'Pregnancies'] = None
df2.loc[6:20,'SkinThickness'] = None
df2.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          1.0       85             66           29.0        0  26.6
# 2          NaN      183             64            0.0        0  23.3
# 3          NaN       89             66           23.0       94  28.1
# 4          NaN      137             40           35.0      168  43.1
# 5          NaN      116             74            0.0        0  25.6
# 6          3.0       78             50            NaN       88  31.0
# 7         10.0      115              0            NaN        0  35.3
# 8          2.0      197             70            NaN      543  30.5
# 9          8.0      125             96            NaN        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                     0.627   50        1         100
# 1                     0.351   31        0          62
# 2                     0.672   32        1          64
# 3                     0.167   21        0          42
# 4                     2.288   33        1          66
# 5                     0.201   30        0          60
# 6                     0.248   26        1          52
# 7                     0.134   29        0          58
# 8                     0.158   53        1         106
# 9                     0.232   54        1         108

# %%
df2.isnull().sum()
# Out:
# Pregnancies                  4
# Glucose                      0
# BloodPressure                0
# SkinThickness               15
# Insulin                      0
# BMI                          0
# DiabetesPedigreeFunction     0
# Age                          0
# Outcome                      0
# double_age                   0
# dtype: int64

# %%
df[['Pregnancies', 'Outcome']]
# Out:
#      Pregnancies  Outcome
# 0              6        1
# 1              1        0
# 2              8        1
# 3              1        0
# 4              0        1
# ..           ...      ...
# 763           10        0
# 764            2        0
# 765            5        0
# 766            1        1
# 767            1        0
#
# [768 rows x 2 columns]

# %%
df[df.index==1]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome  double_age
# 1                     0.351   31        0          62

# %%
df[df.index.isin(range(2,10))]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome  double_age
# 2                     0.672   32        1          64
# 3                     0.167   21        0          42
# 4                     2.288   33        1          66
# 5                     0.201   30        0          60
# 6                     0.248   26        1          52
# 7                     0.134   29        0          58
# 8                     0.158   53        1         106
# 9                     0.232   54        1         108

# %%
df[df.Outcome == 1]
df.iloc[1:3,1:5]
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin
# 1       85             66             29        0
# 2      183             64              0        0

# %%
df3 = df2.copy()
df3 = df3.dropna()
df3.shape
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72           35.0        0  33.6
# 1            1.0       85             66           29.0        0  26.6
# 21           8.0       99             84            0.0        0  35.4
# 22           7.0      196             90            0.0        0  39.8
# 23           9.0      119             80           35.0        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 21                      0.388   50        0         100
# 22                      0.451   41        1          82
# 23                      0.263   29        1          58
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [749 rows x 10 columns]

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72           35.0        0  33.6
# 1            1.0       85             66           29.0        0  26.6
# 21           8.0       99             84            0.0        0  35.4
# 22           7.0      196             90            0.0        0  39.8
# 23           9.0      119             80           35.0        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 21                      0.388   50        0         100
# 22                      0.451   41        1          82
# 23                      0.263   29        1          58
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [749 rows x 10 columns]

# %%
df3 = df2.copy()
# Get the mean of Pregnancies
mean_value = df3['Pregnancies'].mean()
# Fill missing values using .fillna()
df3 = df3.fillna(mean_value)
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0       6.000000      148             72           35.0        0  33.6
# 1       1.000000       85             66           29.0        0  26.6
# 2       3.846859      183             64            0.0        0  23.3
# 3       3.846859       89             66           23.0       94  28.1
# 4       3.846859      137             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763    10.000000      101             76           48.0      180  32.9
# 764     2.000000      122             70           27.0        0  36.8
# 765     5.000000      121             72           23.0      112  26.2
# 766     1.000000      126             60            0.0        0  30.1
# 767     1.000000       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 2                       0.672   32        1          64
# 3                       0.167   21        0          42
# 4                       2.288   33        1          66
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [768 rows x 10 columns]

# %%
df3 = df2.copy()
# Get the median of Pregnancies
median_value = df3['Pregnancies'].median()
# Fill missing values using .fillna()
df3 = df3.fillna(median_value)
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72           35.0        0  33.6
# 1            1.0       85             66           29.0        0  26.6
# 2            3.0      183             64            0.0        0  23.3
# 3            3.0       89             66           23.0       94  28.1
# 4            3.0      137             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  double_age
# 0                       0.627   50        1         100
# 1                       0.351   31        0          62
# 2                       0.672   32        1          64
# 3                       0.167   21        0          42
# 4                       2.288   33        1          66
# ..                        ...  ...      ...         ...
# 763                     0.171   63        0         126
# 764                     0.340   27        0          54
# 765                     0.245   30        0          60
# 766                     0.349   47        1          94
# 767                     0.315   23        0          46
#
# [768 rows x 10 columns]

# %%
df3 = df2.copy()
# Get the mode of Pregnancies
mode_value = df3['Pregnancies'].mode()[0]
# Fill missing values using .fillna()
df3 = df3.fillna(mode_value)
print(mode_value)
# Out:
# 1.0

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4],['f',5]],
                   columns=['letter', 'number'])

# %%
pd.concat([df1,df2], ignore_index=True)
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4
# 4      f       5

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [50, 61, 72, 84]})

# %%
df1.merge(df2, left_on='lkey', right_on='rkey',suffixes = ('_rollNo','_Marks'))
# Out:
#   lkey  value_rollNo rkey  value_Marks
# 0  foo             1  foo           50
# 1  foo             1  foo           84
# 2  foo             5  foo           50
# 3  foo             5  foo           84
# 4  bar             2  bar           61
# 5  baz             3  baz           72

# %%
indices = np.where(df['Pregnancies'] > 13)
plt.figure(figsize = (10,10))
plt.pie(indices[0],autopct = "%1.2f%%", startangle = 90,counterclock = False,shadow = True)
plt.title("Number of Pregnancies")
plt.show()

# %%
indices[0]
# Out:
# array([ 88, 159, 298, 455], dtype=int64)

# %%
df['Pregnancies'][88]
# Out:
# 15
